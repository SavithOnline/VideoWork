# %%
from manim import*

# %%
# %%manim -qm -v WARNING svgindices
#
# class svgindices(Scene):
#     def construct(self):
#         svg = SVGMobject(r"C:\Users\savit\Downloads\Mathematics Animations\Video1\svg01.svg", color=WHITE).scale_to_fit_height(7)
#         self.add(svg, index_labels(svg).set_color(RED))
# Out:
# Manim Community v0.19.0

# %%
# %%manim -qm -v WARNING svgindices
#
# class svgindices(Scene):
#     def construct(self):
#         svg = SVGMobject(r"C:\Users\savit\Downloads\Mathematics Animations\Video1\svg02.svg", color=WHITE).scale_to_fit_height(7)
#         self.camera.background_color = "#e0f7fa"
#         self.add(svg, index_labels(svg).set_color(RED))
# Out:
# Manim Community v0.19.0

# %%
# %%manim -qm -v WARNING svgindices
#
# class svgindices(Scene):
#     def construct(self):
#         svg = SVGMobject(r"C:\Users\savit\Downloads\Mathematics Animations\Video1\SVG03.svg", color=WHITE).scale_to_fit_height(7)
#         self.camera.background_color = "#e0f7fa"
#         self.add(svg, index_labels(svg).set_color(RED))
# Out:
# Manim Community v0.19.0
